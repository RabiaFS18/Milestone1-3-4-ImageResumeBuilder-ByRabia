# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiaFS18/Milestone1-3-4-ImageResumeBuilder-ByRabia/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-agents

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] userdata.get('OPENAI_API_KEY')
